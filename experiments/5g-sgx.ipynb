# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

func_df = pd.read_csv('/home/nssl/graphs/data/functional-latency')
tot_df = pd.read_csv('/home/nssl/graphs/data/total-latency')

# %%
func_df.head()
# Out:
#    Functional Latency (us) External Module  Isolation
# 0                       53             UDM  Container
# 1                       50             UDM  Container
# 2                       50             UDM  Container
# 3                       50             UDM  Container
# 4                       49             UDM  Container

# %%
tot_df.head()
# Out:
#    Total Latency (us) External Module Isolation
# 0                 132             UDM       SGX
# 1                 130             UDM       SGX
# 2                 129             UDM       SGX
# 3                 130             UDM       SGX
# 4                 141             UDM       SGX

# %%
udm_data = pd.read_csv('/home/nssl/graphs/data/final/udm-data')
ausf_data = pd.read_csv('/home/nssl/graphs/data/final/ausf-data')
# udm_data.describe()
ausf_data.describe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 udm_data = pd.read_csv('/home/nssl/graphs/data/final/udm-data')
#       2 ausf_data = pd.read_csv('/home/nssl/graphs/data/final/ausf-data')
#       3 # udm_data.describe()
#
# ...

# %%
var1=["udm-func","udm-func-sgx","udm-tot","udm-tot-sgx"]
var2=["ausf-func","ausf-func-sgx","ausf-tot","ausf-tot-sgx"]
for i in range(4):
    print(f'{var1[i]} Mean: {udm_data[var1[i]].mean()}, Median: {udm_data[var1[i]].median()}')
print('---------------------------------------')
for i in range(4):
    print(f'{var2[i]} Mean: {ausf_data[var2[i]].mean()}, Median: {ausf_data[var2[i]].median()}')
# Out:
# udm-func Mean: 50.3, Median: 50.0
# udm-func-sgx Mean: 60.44, Median: 60.0
# udm-tot Mean: 75.18, Median: 70.0
# udm-tot-sgx Mean: 134.91, Median: 130.0
# ---------------------------------------
# ausf-func Mean: 34.28, Median: 33.0
# ausf-func-sgx Mean: 45.18, Median: 43.0
# ausf-tot Mean: 59.0, Median: 53.0
# ausf-tot-sgx Mean: 121.06, Median: 114.5

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x=func_df['External Module'], y=func_df['Functional Latency (us)'],
            hue=func_df['Isolation'], palette=["b", "g"], width=0.2, linewidth=1, fliersize=3, hue_order=['Container','SGX'])
# Out:
# <Axes: xlabel='External Module', ylabel='Functional Latency (us)'>

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x=tot_df['External Module'], y=tot_df['Total Latency (us)'],
            hue=tot_df['Isolation'], palette=["b", "g"], width=0.2, linewidth=1, fliersize=3, hue_order=['Container','SGX'])
# Out:
# <Axes: xlabel='External Module', ylabel='Total Latency (us)'>

# %%
enc_ld = pd.read_csv('/home/nssl/graphs/data/enclave-load-times/enclave-load-times')

# %%
enc_ld.head()
# Out:
#    Enclave Load Time (mins) External Module
# 0                  0.972716             UDM
# 1                  0.957275             UDM
# 2                  0.965529             UDM
# 3                  0.992299             UDM
# 4                  0.964581             UDM

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x=enc_ld['External Module'], y=enc_ld['Enclave Load Time (mins)'],
            width=0.2, linewidth=1, fliersize=3)
# Out:
# <Axes: xlabel='External Module', ylabel='Enclave Load Time (mins)'>

# %%
init_resp = pd.read_csv('/home/nssl/graphs/data/initial-response')
stable_resp = pd.read_csv('/home/nssl/graphs/data/stable-response')
stable_resp.describe()
# Out:
#               time
# count   594.000000
# mean    813.902357
# std     356.467634
# min     312.000000
# 25%     462.250000
# 50%     807.000000
# 75%    1133.000000
# max    1834.000000

# %%
init_resp.head()
# Out:
#      time module
# 0  22.996    UDM
# 1  22.517    UDM
# 2  22.434    UDM
# 3  22.887    UDM
# 4  22.900    UDM

# %%
ausf_sgx_resp = pd.read_csv('/home/nssl/graphs/data/ausf.resp.sgx')
ausf_sgx_resp.describe()
# Out:
#               1263
# count    89.000000
# mean   1207.539326
# std      98.563784
# min    1027.000000
# 25%    1111.000000
# 50%    1233.000000
# 75%    1276.000000
# max    1487.000000

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x=stable_resp['module'], y=stable_resp['time'],
            hue=stable_resp['Isolation'], palette=["b", "g"], width=0.2, 
            linewidth=1, fliersize=3, hue_order=['Container','SGX'])
# Out:
# <Axes: xlabel='module', ylabel='time'>

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x=init_resp['module'], y=init_resp['time'],
            width=0.2, linewidth=1, fliersize=3)
# Out:
# <Axes: xlabel='module', ylabel='time'>

# %%
udm_sgx_stats_2 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/udm/sgx-stats.2')
udm_sgx_stats_2.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    93.000000    93.000000     100.000000  100.0  100.0
# mean   1598.698925  1504.698925  140570.610000   82.0    0.0
# std       7.405616     7.405616     567.880659    0.0    0.0
# min    1582.000000  1488.000000  140012.000000   82.0    0.0
# 25%    1593.000000  1499.000000  140232.250000   82.0    0.0
# 50%    1599.000000  1505.000000  140371.000000   82.0    0.0
# 75%    1605.000000  1511.000000  140666.000000   82.0    0.0
# max    1619.000000  1525.000000  143206.000000   82.0    0.0

# %%
sns.boxplot(data=udm_sgx_stats_2[['EENTERs','EEXITs']])
# Out:
# <Axes: >

# %%
udm_sgx_stats_1 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/udm/sgx-stats.1')
udm_sgx_stats_1.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    95.000000    95.000000     100.000000  100.0  100.0
# mean   1507.652632  1413.652632  140437.840000   82.0    0.0
# std       6.242900     6.242900     364.802997    0.0    0.0
# min    1494.000000  1400.000000  140014.000000   82.0    0.0
# 25%    1503.000000  1409.000000  140214.000000   82.0    0.0
# 50%    1508.000000  1414.000000  140320.000000   82.0    0.0
# 75%    1512.000000  1418.000000  140593.500000   82.0    0.0
# max    1522.000000  1428.000000  142301.000000   82.0    0.0

# %%
udm_sgx_stats_2 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/udm/sgx-stats.2')
udm_sgx_stats_2.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    93.000000    93.000000     100.000000  100.0  100.0
# mean   1598.698925  1504.698925  140570.610000   82.0    0.0
# std       7.405616     7.405616     567.880659    0.0    0.0
# min    1582.000000  1488.000000  140012.000000   82.0    0.0
# 25%    1593.000000  1499.000000  140232.250000   82.0    0.0
# 50%    1599.000000  1505.000000  140371.000000   82.0    0.0
# 75%    1605.000000  1511.000000  140666.000000   82.0    0.0
# max    1619.000000  1525.000000  143206.000000   82.0    0.0

# %%
udm_sgx_stats_3 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/udm/sgx-stats.3')
udm_sgx_stats_3.describe()
# Out:
#           EENTERs      EEXITs           AEXs   SYNC  ASYNC
# count    96.00000    96.00000     100.000000  100.0  100.0
# mean   1689.62500  1595.62500  140715.790000   82.0    0.0
# std       7.05803     7.05803     850.978798    0.0    0.0
# min    1673.00000  1579.00000  139994.000000   82.0    0.0
# 25%    1684.00000  1590.00000  140237.750000   82.0    0.0
# 50%    1689.00000  1595.00000  140370.500000   82.0    0.0
# 75%    1695.00000  1601.00000  140996.250000   82.0    0.0
# max    1703.00000  1609.00000  145494.000000   82.0    0.0

# %%
temp = pd.read_csv('/home/nssl/graphs/data/sgx-stats/udm/temp')
temp.describe()
# Out:
#            EENTER       EEXIT          AEX
# count   93.000000   93.000000    93.000000
# mean    81.215054   81.215054    -7.322581
# std      7.850297    7.850297   381.971976
# min     65.000000   65.000000 -1065.000000
# 25%     76.000000   76.000000  -166.000000
# 50%     81.000000   81.000000   -13.000000
# 75%     85.000000   85.000000   188.000000
# max    103.000000  103.000000  1024.000000

# %%
sns.boxplot(data=udm_sgx_stats_1[['EENTERs','EEXITs']])
# Out:
# <Axes: >

# %%
ausf_sgx_stats_1 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/ausf/sgx-stats.1')
ausf_sgx_stats_1.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    93.000000    93.000000     100.000000  100.0  100.0
# mean   1537.838710  1443.838710  140475.710000   82.0    0.0
# std       6.582735     6.582735     331.131891    0.0    0.0
# min    1522.000000  1428.000000  140028.000000   82.0    0.0
# 25%    1533.000000  1439.000000  140243.750000   82.0    0.0
# 50%    1539.000000  1445.000000  140380.000000   82.0    0.0
# 75%    1543.000000  1449.000000  140704.250000   82.0    0.0
# max    1553.000000  1459.000000  141484.000000   82.0    0.0

# %%
ausf_sgx_stats_2 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/ausf/sgx-stats.2')
ausf_sgx_stats_2.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    94.000000    94.000000     100.000000  100.0  100.0
# mean   1629.244681  1535.255319  140426.480000   82.0    0.0
# std       8.190850     8.149063     326.679606    0.0    0.0
# min    1597.000000  1504.000000  140047.000000   82.0    0.0
# 25%    1625.000000  1531.000000  140229.750000   82.0    0.0
# 50%    1630.000000  1536.000000  140336.000000   82.0    0.0
# 75%    1634.750000  1540.750000  140499.500000   82.0    0.0
# max    1645.000000  1551.000000  141688.000000   82.0    0.0

# %%
ausf_sgx_stats_3 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/ausf/sgx-stats.3')
ausf_sgx_stats_3.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    94.000000    94.000000     100.000000  100.0  100.0
# mean   1720.734043  1626.734043  140752.570000   82.0    0.0
# std       7.372100     7.372100     699.029099    0.0    0.0
# min    1704.000000  1610.000000  140011.000000   82.0    0.0
# 25%    1715.250000  1621.250000  140257.000000   82.0    0.0
# 50%    1721.000000  1627.000000  140496.500000   82.0    0.0
# 75%    1725.000000  1631.000000  141013.000000   82.0    0.0
# max    1742.000000  1648.000000  143844.000000   82.0    0.0

# %%
amf_sgx_stats_1 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/amf/sgx-stats.1')
amf_sgx_stats_1.describe()
# Out:
#            EENTERs       EEXITs          AEXs   SYNC  ASYNC
# count    98.000000    98.000000     100.00000  100.0  100.0
# mean   1536.510204  1442.510204  140437.41000   82.0    0.0
# std       7.425569     7.425569     269.94564    0.0    0.0
# min    1522.000000  1428.000000  140060.00000   82.0    0.0
# 25%    1530.000000  1436.000000  140254.00000   82.0    0.0
# 50%    1537.500000  1443.500000  140354.00000   82.0    0.0
# 75%    1542.750000  1448.750000  140531.25000   82.0    0.0
# max    1549.000000  1455.000000  141054.00000   82.0    0.0

# %%
amf_sgx_stats_2 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/amf/sgx-stats.2')
amf_sgx_stats_2.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    96.000000    96.000000     100.000000  100.0  100.0
# mean   1629.125000  1535.125000  140503.050000   82.0    0.0
# std       6.561851     6.561851     315.251523    0.0    0.0
# min    1614.000000  1520.000000  140048.000000   82.0    0.0
# 25%    1624.750000  1530.750000  140282.750000   82.0    0.0
# 50%    1629.000000  1535.000000  140426.500000   82.0    0.0
# 75%    1633.000000  1539.000000  140632.750000   82.0    0.0
# max    1643.000000  1549.000000  141414.000000   82.0    0.0

# %%
amf_sgx_stats_3 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/amf/sgx-stats.3')
amf_sgx_stats_3.describe()
# Out:
#            EENTERs       EEXITs           AEXs   SYNC  ASYNC
# count    89.000000    89.000000     100.000000  100.0  100.0
# mean   1720.516854  1626.516854  140941.650000   82.0    0.0
# std       7.678353     7.678353     884.162383    0.0    0.0
# min    1707.000000  1613.000000  140031.000000   82.0    0.0
# 25%    1715.000000  1621.000000  140307.500000   82.0    0.0
# 50%    1720.000000  1626.000000  140630.000000   82.0    0.0
# 75%    1725.000000  1631.000000  141307.750000   82.0    0.0
# max    1743.000000  1649.000000  144568.000000   82.0    0.0

# %%
amf_sgx_stats_4 = pd.read_csv('/home/nssl/graphs/data/sgx-stats/amf/sgx-stats.4')
amf_sgx_stats_4.describe()
# Out:
#            EENTERs       EEXITs           AEXs  SYNC  ASYNC
# count    38.000000    38.000000      40.000000  40.0   40.0
# mean   1811.736842  1717.736842  140465.850000  82.0    0.0
# std       7.582641     7.582641     512.820584   0.0    0.0
# min    1796.000000  1702.000000  140056.000000  82.0    0.0
# 25%    1807.000000  1713.000000  140218.750000  82.0    0.0
# 50%    1811.000000  1717.000000  140291.000000  82.0    0.0
# 75%    1816.750000  1722.750000  140434.250000  82.0    0.0
# max    1829.000000  1735.000000  142346.000000  82.0    0.0

# %%
data = pd.read_csv('/home/nssl/graphs/data/amf-ext.sgx', header=None)
data.describe()
# Out:
#                 0           1
# count  100.000000  100.000000
# mean    37.490000  114.340000
# std      4.164533   13.688615
# min     33.000000  101.000000
# 25%     35.000000  105.000000
# 50%     36.000000  107.500000
# 75%     40.000000  122.250000
# max     55.000000  159.000000

# %%
resptime = pd.read_csv('/home/nssl/graphs/data/amf.init.resp', header=None)
resptime.describe()
# Out:
#                0
# count  10.000000
# mean   22.536000
# std     0.224991
# min    22.238000
# 25%    22.336750
# 50%    22.553500
# 75%    22.735000
# max    22.816000

# %%
empty_workload = pd.read_csv('/home/nssl/graphs/data/sgx-stats/empty-workload/sgx-stats.1')
empty_workload.describe()
# Out:
#           EENTERs      EEXITs          AEXs   SYNC  ASYNC
# count  105.000000  105.000000    105.000000  105.0  105.0
# mean   762.466667  680.466667  49657.523810   78.0    0.0
# std      1.407853    1.407853    538.087588    0.0    0.0
# min    762.000000  680.000000  48677.000000   78.0    0.0
# 25%    762.000000  680.000000  49237.000000   78.0    0.0
# 50%    762.000000  680.000000  49674.000000   78.0    0.0
# 75%    762.000000  680.000000  49989.000000   78.0    0.0
# max    768.000000  686.000000  50587.000000   78.0    0.0
